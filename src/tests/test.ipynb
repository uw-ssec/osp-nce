# %%
from PyPDF2 import PdfReader, PdfWriter
pdf_template = PdfReader(open("/home/edouas/MSDS/capstone/osp-nce/assets/extension_review_matrix.pdf", "rb"))
writer = PdfWriter()
pdf_template.get_form_text_fields()
# Out:
# {'Fixed Price terms': None,
#  'Paid in full': '',
#  'All deliverables  submitted': None,
#  'Review Notes': None,
#  'SFI': None,
#  'RemBal': None,
#  'Deficit?': None,
#  'Greater than 25%?': None,
#  'Award lines': None,
#  'TempReq': None,
#  'CostShare': None,
#  'HumSub': None,
#  'AnimalUse': None,
#  'PriorApp': None,
#  'PrevExt?': None,
#  'ExtendInTime?': None,
#  'FedContract?': None,
#  'PI Name': None,
#  'MOD/Worktag ID': None,
#  'FAR clause 5222254': None}

# %%
import pandas as pd
column_names = [
            "ID",
            "StartTime",
            "CompletionTime",
            "Email",
            "Name",
            "Question",
            "YourName",
            "YourName2",
            "YourEmail",
            "PIName",
            "UWAwardNumber",
            "IsRemainingBalanceMoreThan25Percent",
            "ExplanationForRemainingBalance",
            "RequestedEndDate",
            "isTemporaryExtensionRequest",
            "IsAwardInDeficit",
            "DeficitExplanation",
            "AlternativeNonSponsoredDepartmentalWorktag",
            "allDeliverablesSubmitted",
            "isNIH2PlusExtension",
            "WillPIMaintainMeasurableEffort",
            "ContinuingHumanSubjectsResearch",
            "CurrentIRBProtocolNumber",
            "IRBLocation",
            "IRBExpirationDate",
            "CurrentIRBProtocolNumber2",
            "IRBExpirationDate2",
            "IRBLocation2",
            "CurrentIRBProtocolNumber3",
            "AnimalResearchDone",
            "CurrentIACUCProtocolNumber",
            "IACUCExpirationDate",
            "CurrentIACUCProtocolNumber2",
            "IACUCExpirationDate2",
            "CurrentIACUCProtocolNumber3",
            "IACUCExpirationDate3",
            "CurrentIRBProtocolNumber4",
            "IRBLocation3",
            "IRBExpirationDate3",
            "isNewCostShare",
            "AdditionalComments",
            "AdditionalIRBProtocols",
            "AdditionalIRBProtocolDetails",
            "AdditionalIACUCProtocolDetails",
        ]
xl = pd.read_excel("../../assets/Extensions.xlsx",
                   header = 1,
                   names = column_names)

# %%
xl
# Out:
#         ID           StartTime      CompletionTime            Email  \
# 0        1 2023-07-07 14:13:24 2023-07-07 14:19:37    tmhyre@uw.edu
# 1        2 2023-07-07 14:45:00 2023-07-07 14:45:41   mtilley@uw.edu
# 2        3 2023-07-07 14:13:17 2023-07-07 15:14:03  mikesnow@uw.edu
# 3        4 2023-07-07 16:22:54 2023-07-07 16:30:32  petersoa@uw.edu
# 4        5 2023-07-07 16:35:40 2023-07-07 16:38:12    acs229@uw.edu
# ...    ...                 ...                 ...              ...
# 4206  4223 2025-02-04 13:49:06 2025-02-04 14:09:03       vj7@uw.edu
# 4207  4224 2025-02-04 14:04:23 2025-02-04 14:09:35  dlarsen9@uw.edu
# 4208  4225 2025-02-04 14:09:38 2025-02-04 14:11:44  dlarsen9@uw.edu
# 4209  4226 2025-02-04 14:18:44 2025-02-04 14:28:07     ycho7@uw.edu
# 4210  4227 2025-02-04 14:43:12 2025-02-04 15:23:48  supriyah@uw.edu
#
#                    Name  Question  YourName          YourName2  \
# 0             Tim Mhyre       NaN       NaN          Tim Mhyre
# 1           Matt Tilley       NaN       NaN  Matthew A. Tilley
# 2          Michael Snow       NaN       NaN          Mike Snow
# 3       Alisen Peterson       NaN       NaN    Alisen Peterson
# 4         Amanda Snyder       NaN       NaN      Amanda Snyder
# ...                 ...       ...       ...                ...
# 4206     Veronica Jones       NaN       NaN     Veronica Jones
# 4207      Daniel Larsen       NaN       NaN      Daniel Larsen
# 4208      Daniel Larsen       NaN       NaN      Daniel Larsen
# 4209         Yeilim Cho       NaN       NaN         Yeilim Cho
# 4210  Supriya Hariharan       NaN       NaN  Supriya Hariharan
#
#             YourEmail             PIName  ... CurrentIACUCProtocolNumber3  \
# 0       tmhyre@uw.edu  Dr. Harriet Husky  ...                         NaN
# 1      mtilley@uw.edu         Dr. Tilley  ...                         NaN
# 2     mikesnow@uw.edu          Aaron Lee  ...                         NaN
# 3     Petersoa@uw.edu          Tim Mhyre  ...                         NaN
# 4       acs229@uw.edu             Snyder  ...                         NaN
# ...               ...                ...  ...                         ...
# 4206       vj7@uw.edu    Adam Drewnowski  ...                         NaN
# 4207  dlarsen9@uw.edu          Yaw Nyame  ...                         NaN
# 4208  dlarsen9@uw.edu          Yaw Nyame  ...                         NaN
# 4209     ycho7@uw.edu        Yeilim Cho   ...                         NaN
# 4210  supriyah@uw.edu     Kurtis Heimerl  ...                         NaN
#
#      IACUCExpirationDate3 CurrentIRBProtocolNumber4 IRBLocation3  \
# 0                     NaN                       NaN          NaN
# 1                     NaN              1.234563e+15           UW
# 2                     NaN                       NaN          NaN
# 3                     NaN                       NaN          NaN
# 4                     NaN                       NaN          NaN
# ...                   ...                       ...          ...
# 4206                  NaN                       NaN          NaN
# 4207                  NaN                       NaN          NaN
# 4208                  NaN                       NaN          NaN
# 4209                  NaN                       NaN          NaN
# 4210                  NaN                       NaN          NaN
#
#      IRBExpirationDate3 isNewCostShare  \
# 0                   NaT             No
# 1            2023-10-27             No
# 2                   NaT             No
# 3                   NaT             No
# 4                   NaT             No
# ...                 ...            ...
# 4206                NaT             No
# 4207                NaT             No
# 4208                NaT             No
# 4209                NaT             No
# 4210                NaT             No
#
#                                      AdditionalComments  \
# 0                                            Thank you!
# 1     nothing particular, have a good evening/day/mo...
# 2                                                   NaN
# 3                                             Hi Mara!
# 4                                               Testing
# ...                                                 ...
# 4206                                                NaN
# 4207                                                NaN
# 4208                                                NaN
# 4209  The funding sponsoring agency, the American Ac...
# 4210  Request is for NCE for the extend GR009941, GR...
#
#      AdditionalIRBProtocols AdditionalIRBProtocolDetails  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ...                     ...                          ...
# 4206                    NaN                          NaN
# 4207                    NaN                          NaN
# 4208                    NaN                          NaN
# 4209                    NaN                          NaN
# 4210                    NaN                          NaN
#
#      AdditionalIACUCProtocolDetails
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 4206                            NaN
# 4207                            NaN
# 4208                            NaN
# 4209                            NaN
# 4210                            NaN
#
# [4211 rows x 44 columns]
