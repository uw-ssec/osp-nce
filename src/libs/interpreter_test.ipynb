# %%
import sys
sys.path.append("../")
from libs.erm_autofiller import ERMAutofiller
from libs.sharepoint_connector import SharepointConnector
from libs.sql_connector import SQLConnector
import os

# %%
db_user = os.getenv("RAD_USER")
db_password = os.getenv("RAD_PASSWORD")
db_server = os.getenv("RAD_SERVER")
db_name = os.getenv("RAD_DATABASE")
client_id = os.getenv("AZURE_CLIENT_ID")
tenant_id = os.getenv("AZURE_TENANT_ID")
env = os.getenv("ENV")

# %%
sql_connector = SQLConnector(
        user=db_user, password=db_password, server=db_server, database=db_name
    )
SharepointConnector = SharepointConnector(
        client_id=client_id, tenant_id=tenant_id
    )

# %%
sharepoint_form = SharepointConnector.read_local_csv()

# %%
ermfiller = ERMAutofiller("MOD45892", "LOCAL", rad_connector=sql_connector,sharepoint_connector=SharepointConnector)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src/pymssql/_pymssql.pyx:650, in pymssql._pymssql.connect()
#
# File src/pymssql/_mssql.pyx:2158, in pymssql._mssql.connect()
#
# File src/pymssql/_mssql.pyx:712, in pymssql._mssql.MSSQLConnection.__init__()
#
# File src/pymssql/_mssql.pyx:1884, in pymssql._mssql.maybe_raise_MSSQLDatabaseException()
#
# File src/pymssql/_mssql.pyx:1901, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File src/pymssql/_pymssql.pyx:659, in pymssql._pymssql.connect()
#
# OperationalError: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\n')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ermfiller = ERMAutofiller("MOD45892", "LOCAL", rad_connector=sql_connector,sharepoint_connector=SharepointConnector)
#
# File ~/Desktop/osp-nce/src/libs/../libs/erm_autofiller.py:62, in ERMAutofiller.__init__(self, mod_id, env, rad_connector, sharepoint_connector)
#      50 """
#      51 Initialize the autofiller by querying/cleaning RAD and Sharepoint data.
#      52
#    (...)
#      59         SharepointConnector object for pulling the extension forms.
#      60 """
#      61 # Query RAD
# ---> 62 df_rad = rad_connector.query_from_file(
#      63     self.RAD_QUERY_FILE, params={"mod_id": mod_id}
#      64 )
#      66 if env != "LOCAL":
#      67     # Pull extension forms from sharepoint and query for the relevant mod
#      68     df_sharepoint = (
#      69         sharepoint_connector.read_extension_forms_from_short_link(
#      70             self.SHORT_LINK
#      71         )
#      72     )
#
# File ~/Desktop/osp-nce/src/libs/../libs/sql_connector.py:81, in SQLConnector.query_from_file(self, query_path, params)
#      78 with open(query_path, "r", encoding="utf-8") as query_file:
#      79     query = query_file.read()
# ---> 81 with self.engine.connect() as connection:
#      82     return pd.read_sql(query, con=connection, params=params)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/anaconda3/envs/dev/lib/python3.13/site-packages/sqlalchemy/engine/default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File src/pymssql/_pymssql.pyx:659, in pymssql._pymssql.connect()
#
# OperationalError: (pymssql.exceptions.OperationalError) (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (localhost)\nNet-Lib error during Connection refused (61)\n')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
test_df_inputs1 = {
    "awrd.AuthorizedAmount": 100.0,
    "awrd.BilledToDateAmount": 77.0,
    "egc1.isHumanSubjects": "Y",
    "egc1.isAnimalUse": "N",
    "numberPriorExtensions": 0,
    "numberOutStandingPayments": 0,
    "mod.sponsorHasDeadline": "Y",
    "egc1.sponsorDeadlineDate": "2025-03-30",
    "awrd.AwardScheduleEndDate": "2025-04-15",
    "egc1.FECDMSponsorEntityType": "Federal Government",
    "egc1.projectType": "Contract"
}

# %%
# Create a DataFrame with a single row
df1 = pd.DataFrame([test_df_inputs1])

json.loads(bli.process_query_result(df1))

# %%
test_df_inputs2 = {
    "awrd.AuthorizedAmount": 100.0,
    "awrd.BilledToDateAmount": 74.0,
    "egc1.isHumanSubjects": "N",
    "egc1.isAnimalUse": "Y",
    "numberPriorExtensions": 1,
    "numberOutStandingPayments": 1,
    "mod.sponsorHasDeadline": "Y",
    "egc1.sponsorDeadlineDate": "2025-03-30",
    "awrd.AwardScheduleEndDate": "2025-04-15",
    "egc1.FECDMSponsorEntityType": "Federal Government",
    "egc1.projectType": "Grant"
}

# %%
# Create a DataFrame with a single row
df2 = pd.DataFrame([test_df_inputs2])

json.loads(bli.process_query_result(df2))

# %%
test_df_inputs3 = {
    "awrd.AuthorizedAmount": 100.0,
    "awrd.BilledToDateAmount": 103.0,
    "egc1.isHumanSubjects": "N",
    "egc1.isAnimalUse": "Y",
    "numberPriorExtensions": 1,
    "numberOutStandingPayments": 1,
    "mod.sponsorHasDeadline": "Y",
    "egc1.sponsorDeadlineDate": "2025-03-30",
    "awrd.AwardScheduleEndDate": "2025-04-15",
    "egc1.FECDMSponsorEntityType": "Industry",
    "egc1.projectType": "Grant"
}

# %%
# Create a DataFrame with a single row
df3 = pd.DataFrame([test_df_inputs3])

json.loads(bli.process_query_result(df3))
